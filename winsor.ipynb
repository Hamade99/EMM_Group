# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#source https://r-data.pmagunia.com/dataset/r-dataset-package-ecdat-housing

#http://qed.econ.queensu.ca/jae/1996-v11.6/anglin-gencay/

df = pd.read_csv('dataset-66589.csv')

# %%
df
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df[['lotsize', 'price']].plot(kind= 'scatter', x='lotsize', y='price')
# Out:
# <AxesSubplot:xlabel='lotsize', ylabel='price'>

# %%
df[df['driveway']=='yes'][df['recroom']=='yes'][df['bathrms']>=2].plot(kind= 'scatter', x='lotsize', y='price')

plt.plot()
# Out:
# C:\Users\20193635\AppData\Local\Temp/ipykernel_9208/326544169.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['driveway']=='yes'][df['recroom']=='yes'][df['bathrms']>=2].plot(kind= 'scatter', x='lotsize', y='price')
# <AxesSubplot:xlabel='lotsize', ylabel='price'>

# %%
df[df['driveway']=='yes'][df['recroom']=='yes'][df['bathrms']>=2].index
# Out:
# C:\Users\20193635\AppData\Local\Temp/ipykernel_9208/2912208845.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['driveway']=='yes'][df['recroom']=='yes'][df['bathrms']>=2].index
# Int64Index([  9,  57,  87, 108, 126, 128, 129, 216, 231, 273, 306, 314, 321,
#             330, 336, 360, 373, 376, 380, 384, 396, 397, 405, 457, 473, 477,
#             504, 506, 516, 519, 520, 521, 541, 543, 544],
#            dtype='int64')

# %%
#compliment of dataset
df[~df.index.isin(df[df['driveway']=='yes'][df['recroom']=='yes'][df['bathrms']>=2].index)].plot(kind= 'scatter', x='lotsize', y='price')
# Out:
# C:\Users\20193635\AppData\Local\Temp/ipykernel_9208/748949301.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[~df.index.isin(df[df['driveway']=='yes'][df['recroom']=='yes'][df['bathrms']>=2].index)].plot(kind= 'scatter', x='lotsize', y='price')
# <AxesSubplot:xlabel='lotsize', ylabel='price'>

# %%
df.describe()
# Out:
#                price       lotsize    bedrooms     bathrms     stories  \
# count     546.000000    546.000000  546.000000  546.000000  546.000000
# mean    68121.597070   5150.265568    2.965201    1.285714    1.807692
# std     26702.670926   2168.158725    0.737388    0.502158    0.868203
# min     25000.000000   1650.000000    1.000000    1.000000    1.000000
# 25%     49125.000000   3600.000000    2.000000    1.000000    1.000000
# 50%     62000.000000   4600.000000    3.000000    1.000000    2.000000
# 75%     82000.000000   6360.000000    3.000000    2.000000    2.000000
# max    190000.000000  16200.000000    6.000000    4.000000    4.000000
#
#          garagepl
# count  546.000000
# mean     0.692308
# std      0.861307
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# plt.plot('lotsize','price', marker='.', data=df)
plt.scatter('lotsize','price', marker='.', data=df, c='black')

# %%
plt(x=df['lotsize'], y=df['price'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9208/3202590175.py in <module>
# ----> 1 plt(x=df['lotsize'], y=df['price'])
#
# TypeError: 'module' object is not callable

# %% [markdown]
# # SNS

# %%
import matplotlib
import seaborn as sns

sns.set(font_scale=1.3)
sns.set_style("darkgrid", {"axes.facecolor": ".95"})

plt.scatter('lotsize','price', marker='.', data=df, c='black')

# %%
sns.plot()
